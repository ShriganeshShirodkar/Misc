# %%
# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en-IN;q=0.9,en;q=0.8,kn;q=0.7,mr;q=0.6" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10151/59042/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1582272766&Signature=S6qE71BL07Wu6xF%2FnjB5a%2BfUWp6mwHPamqrShvMnYghPeA9d7pljEsLtReDCGj0DrH4ES1XDPzBpFp0bTEDFL3Df%2FUIcuZaEuDf%2BD0m3P5AerzqZVU70lvsP9YKJ3%2Bp%2F1LYSb6vbB%2Fq0HKpxZRIbVO%2FFw3J5ntAxsXPFfZOX%2FKUi4%2F%2BEMfaqC9cMsIZg2xpBEd2WNTIe6uxMIEBlKYJYCmfmVZIqtKsRor1rGmBmKS%2F5NcTojHKSileL4aW2VFhobIuNZybO7wermMS5sMtR4IVcy4B53GHpyttfQx748nBTLWaSLxQRJ0aBFZ6FppYn0aBDk6EAKlRBOMLDImvKMQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dtgs-salt-identification-challenge.zip" -O "tgs-salt-identification-challenge.zip" -c
# Out:
# --2020-02-21 06:23:41--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10151/59042/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1582272766&Signature=S6qE71BL07Wu6xF%2FnjB5a%2BfUWp6mwHPamqrShvMnYghPeA9d7pljEsLtReDCGj0DrH4ES1XDPzBpFp0bTEDFL3Df%2FUIcuZaEuDf%2BD0m3P5AerzqZVU70lvsP9YKJ3%2Bp%2F1LYSb6vbB%2Fq0HKpxZRIbVO%2FFw3J5ntAxsXPFfZOX%2FKUi4%2F%2BEMfaqC9cMsIZg2xpBEd2WNTIe6uxMIEBlKYJYCmfmVZIqtKsRor1rGmBmKS%2F5NcTojHKSileL4aW2VFhobIuNZybO7wermMS5sMtR4IVcy4B53GHpyttfQx748nBTLWaSLxQRJ0aBFZ6FppYn0aBDk6EAKlRBOMLDImvKMQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dtgs-salt-identification-challenge.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.197.128, 2607:f8b0:400e:c07::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.197.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 466124588 (445M) [application/zip]
# Saving to: ‘tgs-salt-identification-challenge.zip’
#
# tgs-salt-identifica 100%[===================>] 444.53M  72.2MB/s    in 6.2s
#
# 2020-02-21 06:23:47 (72.2 MB/s) - ‘tgs-salt-identification-challenge.zip’ saved [466124588/466124588]

# %%
# !unzip '/content/tgs-salt-identification-challenge.zip'
from zipfile import ZipFile
zf = ZipFile('train.zip', 'r')
zf.extractall('../content/train')
zf.close()
from zipfile import ZipFile
zf = ZipFile('test.zip', 'r')
zf.extractall('../content/test')
zf.close()
# Out:
# Archive:  /content/tgs-salt-identification-challenge.zip
#   inflating: competition_data.zip
#   inflating: depths.csv
#   inflating: flamingo.zip
#   inflating: sample_submission.csv
#   inflating: test.zip
#   inflating: train.csv
#   inflating: train.zip

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style('white')

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input, Dropout, BatchNormalization, Activation, Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers
import tensorflow as tf
from keras.preprocessing.image import array_to_img, img_to_array, load_img

import time
t_start = time.time()

# %%
version = 4
basic_name = f'Unet_resnet_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# Unet_resnet_v4.model
# Unet_resnet_v4.csv

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %% [markdown]
# ## Data Processing

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
train_df["masks"] = [np.array(load_img("train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5, 0, 'Coverage class')

# %%
#Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5, 1.0, 'Depth distribution')

# %%
# Create train/validation split stratified by salt coverage
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = \
train_test_split(train_df.index.values, 
                 np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1),
                 np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1),
                 train_df.coverage.values, 
                 train_df.z.values, 
                 test_size=0.2, stratify=train_df.coverage_class, random_state=555)

# %% [markdown]
# ### Unet Model

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation==True: x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3))
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate: x = BatchActivate(x)
    return x

# %%
# Build Model
def build_model(input_layer, start_neurons, DropoutRatio=0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons*1, (3,3), activation=None, padding='same')(input_layer)
    conv1 = residual_block(conv1, start_neurons*1)
    conv1 = residual_block(conv1, start_neurons*1, True)
    pool1 = MaxPooling2D((2,2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)
    
    # 50 -> 25
    conv2 = Conv2D(start_neurons*2, (3,3), activation=None, padding='same')(pool1)
    conv2 = residual_block(conv2, start_neurons*2)
    conv2 = residual_block(conv2, start_neurons*2, True)
    pool2 = MaxPooling2D((2,2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)
    
    # 25 -> 12
    conv3 = Conv2D(start_neurons*4, (3,3), activation=None, padding='same')(pool2)
    conv3 = residual_block(conv3, start_neurons*4)
    conv3 = residual_block(conv3, start_neurons*4, True)
    pool3 = MaxPooling2D((2,2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)
    
    # 12 -> 6
    conv4 = Conv2D(start_neurons*8, (3,3), activation=None, padding='same')(pool3)
    conv4 = residual_block(conv4, start_neurons*8)
    conv4 = residual_block(conv4, start_neurons*8, True)
    pool4 = MaxPooling2D((2,2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)
    
    # Middle
    convm = Conv2D(start_neurons*16, (3,3), activation=None, padding='same')(pool4)
    convm = residual_block(convm, start_neurons*16)
    convm = residual_block(convm, start_neurons*16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons*8, (3,3), strides=(2,2), padding='same')(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons*8, (3,3), activation=None, padding='same')(uconv4)
    uconv4 = residual_block(uconv4, start_neurons*8)
    uconv4 = residual_block(uconv4, start_neurons*8, True)
    
    # 12 -> 25
    deconv3 = Conv2DTranspose(start_neurons*4, (3,3), strides=(2,2), padding='valid')(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons*4, (3,3), activation=None, padding='same')(uconv3)
    uconv3 = residual_block(uconv3, start_neurons*4)
    uconv3 = residual_block(uconv3, start_neurons*4, True)
    
    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons*2, (3,3), strides=(2,2), padding='same')(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(DropoutRatio)(uconv2)
    
    uconv2 = Conv2D(start_neurons*2, (3,3), activation=None, padding='same')(uconv2)
    uconv2 = residual_block(uconv2, start_neurons*2)
    uconv2 = residual_block(uconv2, start_neurons*2, True)
    
    # 50 -> 101
    deconv1 = Conv2DTranspose(start_neurons*1, (3,3), strides=(2,2), padding='valid')(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(DropoutRatio)(uconv1)
    
    uconv1 = Conv2D(start_neurons*1, (3,3), activation=None, padding='same')(uconv1)
    uconv1 = residual_block(uconv1, start_neurons*1)
    uconv1 = residual_block(uconv1, start_neurons*1, True)
    
    output_layer_noActi = Conv2D(1, (1,1), padding='same', activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))
        
    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard

# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss

def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %% [markdown]
# ### Data Augmentation

# %%
#Adding Gaussian Noise 
import numpy as np
import os
import cv2
def noisy(noise_typ,image):
    
   if noise_typ == "gauss":
      row,col,ch= image.shape
      mean = 0
      #0.0001=0.783
      var = 0.0001
      sigma = var**0.5
      gauss = np.random.normal(mean,sigma,(row,col,ch))
      gauss = gauss.reshape(row,col,ch)
      noisy = image + gauss
      return noisy

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
x_train = np.append(x_train, [noisy("gauss",x) for x in x_train[0:3200]], axis=0)
y_train = np.append(y_train, [x for x in y_train[0:3200]], axis=0)

print(x_train.shape)
print(y_valid.shape)
# Out:
# (9600, 101, 101, 1)
# (800, 101, 101, 1)

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.5)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.005)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

model1.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 101, 101, 16) 160         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 101, 101, 16) 64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 101, 101, 16) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 101, 101, 16) 2320        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 101, 101, 16) 64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 101, 101, 16) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 101, 101, 16) 2320        activation_48[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 101, 101, 16) 0           conv2d_49[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 101, 101, 16) 64          add_19[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 101, 101, 16) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 101, 101, 16) 2320        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 101, 101, 16) 64          conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 101, 101, 16) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 101, 101, 16) 2320        activation_50[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 101, 101, 16) 0           conv2d_51[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 101, 101, 16) 64          add_20[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 101, 101, 16) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 50, 50, 16)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 50, 50, 16)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 50, 50, 32)   4640        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 50, 50, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 50, 50, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 50, 50, 32)   9248        activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 50, 50, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 50, 50, 32)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 50, 50, 32)   9248        activation_53[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 50, 50, 32)   0           conv2d_54[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 50, 50, 32)   128         add_21[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 50, 50, 32)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 50, 50, 32)   9248        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 50, 50, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 50, 50, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 50, 50, 32)   9248        activation_55[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 50, 50, 32)   0           conv2d_56[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 50, 50, 32)   128         add_22[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 50, 50, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 25, 25, 32)   0           activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 25, 25, 32)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 25, 25, 64)   18496       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 25, 25, 64)   256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 25, 25, 64)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 25, 25, 64)   36928       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 25, 25, 64)   256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 25, 25, 64)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 25, 25, 64)   36928       activation_58[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 25, 25, 64)   0           conv2d_59[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 25, 25, 64)   256         add_23[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 25, 25, 64)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 25, 25, 64)   36928       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 25, 25, 64)   256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 25, 25, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 25, 25, 64)   36928       activation_60[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 25, 25, 64)   0           conv2d_61[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 25, 25, 64)   256         add_24[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 25, 25, 64)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 12, 12, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 128)  73856       dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 128)  147584      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 12, 12, 128)  0           conv2d_64[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 128)  512         add_25[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 128)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 128)  147584      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 128)  512         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 128)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 128)  147584      activation_65[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 12, 12, 128)  0           conv2d_66[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 128)  512         add_26[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 128)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 128)    0           activation_66[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 6, 6, 256)    295168      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 6, 6, 256)    1024        conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 6, 6, 256)    0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 6, 6, 256)    590080      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 6, 6, 256)    1024        conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 6, 6, 256)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 6, 6, 256)    590080      activation_68[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 6, 6, 256)    0           conv2d_69[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 6, 6, 256)    1024        add_27[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 6, 6, 256)    0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 6, 6, 256)    590080      activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 6, 6, 256)    1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 6, 6, 256)    0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 6, 6, 256)    590080      activation_70[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 6, 6, 256)    0           conv2d_71[0][0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 6, 6, 256)    1024        add_28[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 6, 6, 256)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 12, 12, 128)  295040      activation_71[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_5[0][0]
#                                                                  activation_66[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 12, 12, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 12, 12, 128)  295040      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 12, 12, 128)  512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 12, 12, 128)  0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 12, 12, 128)  147584      activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 12, 12, 128)  512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 12, 12, 128)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 12, 12, 128)  147584      activation_73[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 12, 12, 128)  0           conv2d_74[0][0]
#                                                                  conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 12, 12, 128)  512         add_29[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 12, 12, 128)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 12, 12, 128)  147584      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 12, 12, 128)  512         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 12, 12, 128)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 12, 12, 128)  147584      activation_75[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 12, 12, 128)  0           conv2d_76[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 12, 12, 128)  512         add_30[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 12, 12, 128)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 25, 25, 64)   73792       activation_76[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_6[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 25, 25, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 25, 25, 64)   73792       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 25, 25, 64)   256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 25, 25, 64)   0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 25, 25, 64)   36928       activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 25, 25, 64)   256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 25, 25, 64)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 25, 25, 64)   36928       activation_78[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 25, 25, 64)   0           conv2d_79[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 25, 25, 64)   256         add_31[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 25, 25, 64)   0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 25, 25, 64)   36928       activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 25, 25, 64)   256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 25, 25, 64)   0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 25, 25, 64)   36928       activation_80[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 25, 25, 64)   0           conv2d_81[0][0]
#                                                                  add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 25, 25, 64)   256         add_32[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 25, 25, 64)   0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 50, 50, 32)   18464       activation_81[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 50, 50, 64)   0           conv2d_transpose_7[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 50, 50, 64)   0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 50, 50, 32)   18464       dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 50, 50, 32)   128         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 50, 50, 32)   0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 50, 50, 32)   9248        activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 50, 50, 32)   128         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 50, 50, 32)   0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 50, 50, 32)   9248        activation_83[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 50, 50, 32)   0           conv2d_84[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 50, 50, 32)   128         add_33[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 50, 50, 32)   0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 50, 50, 32)   9248        activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 50, 50, 32)   128         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 50, 50, 32)   0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 50, 50, 32)   9248        activation_85[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 50, 50, 32)   0           conv2d_86[0][0]
#                                                                  add_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 50, 50, 32)   128         add_34[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 50, 50, 32)   0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 101, 101, 16) 4624        activation_86[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 101, 101, 32) 0           conv2d_transpose_8[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 101, 101, 32) 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 101, 101, 16) 4624        dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 101, 101, 16) 64          conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 101, 101, 16) 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 101, 101, 16) 2320        activation_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 101, 101, 16) 64          conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 101, 101, 16) 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 101, 101, 16) 2320        activation_88[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 101, 101, 16) 0           conv2d_89[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 101, 101, 16) 64          add_35[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 101, 101, 16) 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 101, 101, 16) 2320        activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 101, 101, 16) 64          conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 101, 101, 16) 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 101, 101, 16) 2320        activation_90[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 101, 101, 16) 0           conv2d_91[0][0]
#                                                                  add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 101, 101, 16) 64          add_36[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 101, 101, 16) 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 101, 101, 1)  17          activation_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 101, 101, 1)  0           conv2d_92[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=15, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name, monitor='my_iou_metric', mode='max',
                                   save_best_only=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode='max', factor=0.5, patience=5,
                              min_lr=0.0001, verbose=1)

epochs = 100
batch_size = 128

t_model1_start = time.time()
history = model1.fit(x_train, y_train,
                     validation_data = [x_valid, y_valid], 
                     epochs = epochs, 
                     batch_size = batch_size, 
                     callbacks = [early_stopping, model_checkpoint, reduce_lr],
                     verbose = 2)
t_model1_end = time.time()
print(f"Run time = {(t_model1_end-t_model1_start)/3600} hours")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 6400 samples, validate on 800 samples
# Epoch 1/100
#  - 35s - loss: 0.4844 - my_iou_metric: 0.2327 - val_loss: 8.7015 - val_my_iou_metric: 0.0604
#
# Epoch 00001: my_iou_metric improved from -inf to 0.23270, saving model to Unet_resnet_v4.model
# Epoch 2/100
#  - 18s - loss: 0.3532 - my_iou_metric: 0.4593 - val_loss: 1.0887 - val_my_iou_metric: 0.3900
#
# Epoch 00002: my_iou_metric improved from 0.23270 to 0.45933, saving model to Unet_resnet_v4.model
# Epoch 3/100
#  - 18s - loss: 0.2898 - my_iou_metric: 0.5269 - val_loss: 3.9443 - val_my_iou_metric: 0.3900
#
# Epoch 00003: my_iou_metric improved from 0.45933 to 0.52691, saving model to Unet_resnet_v4.model
# Epoch 4/100
#  - 18s - loss: 0.2718 - my_iou_metric: 0.5294 - val_loss: 0.9441 - val_my_iou_metric: 0.1485
#
# Epoch 00004: my_iou_metric improved from 0.52691 to 0.52944, saving model to Unet_resnet_v4.model
# Epoch 5/100
#  - 18s - loss: 0.2501 - my_iou_metric: 0.5310 - val_loss: 0.5377 - val_my_iou_metric: 0.3044
#
# Epoch 00005: my_iou_metric improved from 0.52944 to 0.53102, saving model to Unet_resnet_v4.model
# Epoch 6/100
#  - 18s - loss: 0.2347 - my_iou_metric: 0.5509 - val_loss: 0.5721 - val_my_iou_metric: 0.3355
#
# Epoch 00006: my_iou_metric improved from 0.53102 to 0.55087, saving model to Unet_resnet_v4.model
# Epoch 7/100
#  - 18s - loss: 0.2224 - my_iou_metric: 0.5692 - val_loss: 0.3397 - val_my_iou_metric: 0.5545
#
# Epoch 00007: my_iou_metric improved from 0.55087 to 0.56920, saving model to Unet_resnet_v4.model
# Epoch 8/100
#  - 18s - loss: 0.2188 - my_iou_metric: 0.5879 - val_loss: 0.2521 - val_my_iou_metric: 0.5820
#
# Epoch 00008: my_iou_metric improved from 0.56920 to 0.58794, saving model to Unet_resnet_v4.model
# Epoch 9/100
#  - 18s - loss: 0.2092 - my_iou_metric: 0.5971 - val_loss: 0.2731 - val_my_iou_metric: 0.5974
#
# Epoch 00009: my_iou_metric improved from 0.58794 to 0.59711, saving model to Unet_resnet_v4.model
# Epoch 10/100
#  - 18s - loss: 0.1999 - my_iou_metric: 0.6154 - val_loss: 0.2523 - val_my_iou_metric: 0.6250
#
# Epoch 00010: my_iou_metric improved from 0.59711 to 0.61541, saving model to Unet_resnet_v4.model
# Epoch 11/100
#  - 18s - loss: 0.1975 - my_iou_metric: 0.6201 - val_loss: 0.3186 - val_my_iou_metric: 0.5951
#
# Epoch 00011: my_iou_metric improved from 0.61541 to 0.62011, saving model to Unet_resnet_v4.model
# Epoch 12/100
#  - 18s - loss: 0.1927 - my_iou_metric: 0.6277 - val_loss: 0.3789 - val_my_iou_metric: 0.4464
#
# Epoch 00012: my_iou_metric improved from 0.62011 to 0.62770, saving model to Unet_resnet_v4.model
# Epoch 13/100
#  - 18s - loss: 0.1899 - my_iou_metric: 0.6366 - val_loss: 0.4226 - val_my_iou_metric: 0.5164
#
# Epoch 00013: my_iou_metric improved from 0.62770 to 0.63656, saving model to Unet_resnet_v4.model
# Epoch 14/100
#  - 18s - loss: 0.1914 - my_iou_metric: 0.6371 - val_loss: 0.3107 - val_my_iou_metric: 0.6346
#
# Epoch 00014: my_iou_metric improved from 0.63656 to 0.63709, saving model to Unet_resnet_v4.model
# Epoch 15/100
#  - 18s - loss: 0.1889 - my_iou_metric: 0.6313 - val_loss: 0.2687 - val_my_iou_metric: 0.5013
#
# Epoch 00015: my_iou_metric did not improve from 0.63709
# Epoch 16/100
#  - 18s - loss: 0.1768 - my_iou_metric: 0.6452 - val_loss: 0.1898 - val_my_iou_metric: 0.6253
#
# Epoch 00016: my_iou_metric improved from 0.63709 to 0.64519, saving model to Unet_resnet_v4.model
# Epoch 17/100
#  - 18s - loss: 0.1733 - my_iou_metric: 0.6611 - val_loss: 0.3006 - val_my_iou_metric: 0.6120
#
# Epoch 00017: my_iou_metric improved from 0.64519 to 0.66114, saving model to Unet_resnet_v4.model
# Epoch 18/100
#  - 18s - loss: 0.1701 - my_iou_metric: 0.6638 - val_loss: 0.2267 - val_my_iou_metric: 0.6675
#
# Epoch 00018: my_iou_metric improved from 0.66114 to 0.66381, saving model to Unet_resnet_v4.model
# Epoch 19/100
#  - 18s - loss: 0.1659 - my_iou_metric: 0.6622 - val_loss: 0.2081 - val_my_iou_metric: 0.6590
#
# Epoch 00019: my_iou_metric did not improve from 0.66381
# Epoch 20/100
#  - 18s - loss: 0.1614 - my_iou_metric: 0.6768 - val_loss: 0.1950 - val_my_iou_metric: 0.6492
#
# Epoch 00020: my_iou_metric improved from 0.66381 to 0.67683, saving model to Unet_resnet_v4.model
# Epoch 21/100
#  - 18s - loss: 0.1588 - my_iou_metric: 0.6801 - val_loss: 0.2526 - val_my_iou_metric: 0.6805
#
# Epoch 00021: my_iou_metric improved from 0.67683 to 0.68006, saving model to Unet_resnet_v4.model
# Epoch 22/100
#  - 18s - loss: 0.1538 - my_iou_metric: 0.6862 - val_loss: 0.3371 - val_my_iou_metric: 0.4674
#
# Epoch 00022: my_iou_metric improved from 0.68006 to 0.68616, saving model to Unet_resnet_v4.model
# Epoch 23/100
#  - 18s - loss: 0.1596 - my_iou_metric: 0.6870 - val_loss: 0.2338 - val_my_iou_metric: 0.6143
#
# Epoch 00023: my_iou_metric improved from 0.68616 to 0.68700, saving model to Unet_resnet_v4.model
# Epoch 24/100
#  - 18s - loss: 0.1517 - my_iou_metric: 0.6936 - val_loss: 0.2004 - val_my_iou_metric: 0.6380
#
# Epoch 00024: my_iou_metric improved from 0.68700 to 0.69364, saving model to Unet_resnet_v4.model
# Epoch 25/100
#  - 18s - loss: 0.1518 - my_iou_metric: 0.6947 - val_loss: 0.2393 - val_my_iou_metric: 0.5605
#
# Epoch 00025: my_iou_metric improved from 0.69364 to 0.69472, saving model to Unet_resnet_v4.model
# Epoch 26/100
#  - 18s - loss: 0.1484 - my_iou_metric: 0.7030 - val_loss: 0.3325 - val_my_iou_metric: 0.4804
#
# Epoch 00026: my_iou_metric improved from 0.69472 to 0.70295, saving model to Unet_resnet_v4.model
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 27/100
#  - 18s - loss: 0.1349 - my_iou_metric: 0.7188 - val_loss: 0.1609 - val_my_iou_metric: 0.7057
#
# Epoch 00027: my_iou_metric improved from 0.70295 to 0.71875, saving model to Unet_resnet_v4.model
# Epoch 28/100
#  - 18s - loss: 0.1335 - my_iou_metric: 0.7252 - val_loss: 0.1555 - val_my_iou_metric: 0.6989
#
# Epoch 00028: my_iou_metric improved from 0.71875 to 0.72516, saving model to Unet_resnet_v4.model
# Epoch 29/100
#  - 18s - loss: 0.1289 - my_iou_metric: 0.7268 - val_loss: 0.3196 - val_my_iou_metric: 0.6473
#
# Epoch 00029: my_iou_metric improved from 0.72516 to 0.72680, saving model to Unet_resnet_v4.model
# Epoch 30/100
#  - 18s - loss: 0.1267 - my_iou_metric: 0.7332 - val_loss: 0.1418 - val_my_iou_metric: 0.7331
#
# Epoch 00030: my_iou_metric improved from 0.72680 to 0.73323, saving model to Unet_resnet_v4.model
# Epoch 31/100
#  - 18s - loss: 0.1228 - my_iou_metric: 0.7405 - val_loss: 0.1484 - val_my_iou_metric: 0.7256
#
# Epoch 00031: my_iou_metric improved from 0.73323 to 0.74045, saving model to Unet_resnet_v4.model
# Epoch 32/100
#  - 18s - loss: 0.1249 - my_iou_metric: 0.7277 - val_loss: 0.1958 - val_my_iou_metric: 0.6984
#
# Epoch 00032: my_iou_metric did not improve from 0.74045
# Epoch 33/100
#  - 18s - loss: 0.1196 - my_iou_metric: 0.7393 - val_loss: 0.1356 - val_my_iou_metric: 0.7538
#
# Epoch 00033: my_iou_metric did not improve from 0.74045
# Epoch 34/100
#  - 18s - loss: 0.1230 - my_iou_metric: 0.7327 - val_loss: 0.1795 - val_my_iou_metric: 0.7238
#
# Epoch 00034: my_iou_metric did not improve from 0.74045
# Epoch 35/100
#  - 18s - loss: 0.1158 - my_iou_metric: 0.7405 - val_loss: 0.1517 - val_my_iou_metric: 0.6774
#
# Epoch 00035: my_iou_metric improved from 0.74045 to 0.74050, saving model to Unet_resnet_v4.model
# Epoch 36/100
#  - 18s - loss: 0.1179 - my_iou_metric: 0.7442 - val_loss: 0.1785 - val_my_iou_metric: 0.7281
#
# Epoch 00036: my_iou_metric improved from 0.74050 to 0.74423, saving model to Unet_resnet_v4.model
# Epoch 37/100
#  - 18s - loss: 0.1173 - my_iou_metric: 0.7375 - val_loss: 0.1888 - val_my_iou_metric: 0.7110
#
# Epoch 00037: my_iou_metric did not improve from 0.74423
# Epoch 38/100
#  - 18s - loss: 0.1181 - my_iou_metric: 0.7387 - val_loss: 0.1527 - val_my_iou_metric: 0.7154
#
# Epoch 00038: my_iou_metric did not improve from 0.74423
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 39/100
#  - 18s - loss: 0.1082 - my_iou_metric: 0.7503 - val_loss: 0.1280 - val_my_iou_metric: 0.7528
#
# Epoch 00039: my_iou_metric improved from 0.74423 to 0.75030, saving model to Unet_resnet_v4.model
# Epoch 40/100
#  - 18s - loss: 0.1031 - my_iou_metric: 0.7542 - val_loss: 0.1314 - val_my_iou_metric: 0.7477
#
# Epoch 00040: my_iou_metric improved from 0.75030 to 0.75420, saving model to Unet_resnet_v4.model
# Epoch 41/100
#  - 18s - loss: 0.0993 - my_iou_metric: 0.7599 - val_loss: 0.1273 - val_my_iou_metric: 0.7589
#
# Epoch 00041: my_iou_metric improved from 0.75420 to 0.75988, saving model to Unet_resnet_v4.model
# Epoch 42/100
#  - 18s - loss: 0.0964 - my_iou_metric: 0.7596 - val_loss: 0.1408 - val_my_iou_metric: 0.7374
#
# Epoch 00042: my_iou_metric did not improve from 0.75988
# Epoch 43/100
#  - 18s - loss: 0.1004 - my_iou_metric: 0.7593 - val_loss: 0.1342 - val_my_iou_metric: 0.7489
#
# Epoch 00043: my_iou_metric did not improve from 0.75988
# Epoch 44/100
#  - 18s - loss: 0.0970 - my_iou_metric: 0.7616 - val_loss: 0.1377 - val_my_iou_metric: 0.7468
#
# Epoch 00044: my_iou_metric improved from 0.75988 to 0.76158, saving model to Unet_resnet_v4.model
# Epoch 45/100
#  - 18s - loss: 0.0933 - my_iou_metric: 0.7649 - val_loss: 0.1381 - val_my_iou_metric: 0.7470
#
# Epoch 00045: my_iou_metric improved from 0.76158 to 0.76489, saving model to Unet_resnet_v4.model
# Epoch 46/100
#  - 18s - loss: 0.0923 - my_iou_metric: 0.7611 - val_loss: 0.1419 - val_my_iou_metric: 0.7497
#
# Epoch 00046: my_iou_metric did not improve from 0.76489
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 47/100
#  - 18s - loss: 0.0859 - my_iou_metric: 0.7750 - val_loss: 0.1272 - val_my_iou_metric: 0.7651
#
# Epoch 00047: my_iou_metric improved from 0.76489 to 0.77495, saving model to Unet_resnet_v4.model
# Epoch 48/100
#  - 18s - loss: 0.0832 - my_iou_metric: 0.7760 - val_loss: 0.1308 - val_my_iou_metric: 0.7750
#
# Epoch 00048: my_iou_metric improved from 0.77495 to 0.77603, saving model to Unet_resnet_v4.model
# Epoch 49/100
#  - 18s - loss: 0.0837 - my_iou_metric: 0.7728 - val_loss: 0.1335 - val_my_iou_metric: 0.7642
#
# Epoch 00049: my_iou_metric did not improve from 0.77603
# Epoch 50/100
#  - 18s - loss: 0.0849 - my_iou_metric: 0.7718 - val_loss: 0.1349 - val_my_iou_metric: 0.7610
#
# Epoch 00050: my_iou_metric did not improve from 0.77603
# Epoch 51/100
#  - 18s - loss: 0.0816 - my_iou_metric: 0.7736 - val_loss: 0.1268 - val_my_iou_metric: 0.7710
#
# Epoch 00051: my_iou_metric did not improve from 0.77603
# Epoch 52/100
#  - 18s - loss: 0.0796 - my_iou_metric: 0.7762 - val_loss: 0.1349 - val_my_iou_metric: 0.7740
#
# Epoch 00052: my_iou_metric improved from 0.77603 to 0.77622, saving model to Unet_resnet_v4.model
# Epoch 53/100
#  - 18s - loss: 0.0820 - my_iou_metric: 0.7763 - val_loss: 0.1306 - val_my_iou_metric: 0.7555
#
# Epoch 00053: my_iou_metric improved from 0.77622 to 0.77634, saving model to Unet_resnet_v4.model
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 54/100
#  - 18s - loss: 0.0790 - my_iou_metric: 0.7800 - val_loss: 0.1271 - val_my_iou_metric: 0.7761
#
# Epoch 00054: my_iou_metric improved from 0.77634 to 0.78000, saving model to Unet_resnet_v4.model
# Epoch 55/100
#  - 18s - loss: 0.0772 - my_iou_metric: 0.7821 - val_loss: 0.1267 - val_my_iou_metric: 0.7730
#
# Epoch 00055: my_iou_metric improved from 0.78000 to 0.78213, saving model to Unet_resnet_v4.model
# Epoch 56/100
#  - 18s - loss: 0.0745 - my_iou_metric: 0.7859 - val_loss: 0.1273 - val_my_iou_metric: 0.7746
#
# Epoch 00056: my_iou_metric improved from 0.78213 to 0.78592, saving model to Unet_resnet_v4.model
# Epoch 57/100
#  - 18s - loss: 0.0779 - my_iou_metric: 0.7807 - val_loss: 0.1307 - val_my_iou_metric: 0.7746
#
# Epoch 00057: my_iou_metric did not improve from 0.78592
# Epoch 58/100
#  - 18s - loss: 0.0771 - my_iou_metric: 0.7834 - val_loss: 0.1196 - val_my_iou_metric: 0.7761
#
# Epoch 00058: my_iou_metric did not improve from 0.78592
# Epoch 59/100
#  - 18s - loss: 0.0759 - my_iou_metric: 0.7818 - val_loss: 0.1209 - val_my_iou_metric: 0.7789
#
# Epoch 00059: my_iou_metric did not improve from 0.78592
# Epoch 60/100
#  - 18s - loss: 0.0753 - my_iou_metric: 0.7848 - val_loss: 0.1285 - val_my_iou_metric: 0.7712
#
# Epoch 00060: my_iou_metric did not improve from 0.78592
# Epoch 61/100
#  - 18s - loss: 0.0751 - my_iou_metric: 0.7835 - val_loss: 0.1273 - val_my_iou_metric: 0.7686
#
# Epoch 00061: my_iou_metric did not improve from 0.78592
# Epoch 62/100
#  - 18s - loss: 0.0748 - my_iou_metric: 0.7839 - val_loss: 0.1280 - val_my_iou_metric: 0.7772
#
# Epoch 00062: my_iou_metric did not improve from 0.78592
# Epoch 63/100
#  - 18s - loss: 0.0719 - my_iou_metric: 0.7882 - val_loss: 0.1315 - val_my_iou_metric: 0.7746
#
# Epoch 00063: my_iou_metric improved from 0.78592 to 0.78823, saving model to Unet_resnet_v4.model
# Epoch 64/100
#  - 18s - loss: 0.0731 - my_iou_metric: 0.7865 - val_loss: 0.1237 - val_my_iou_metric: 0.7699
#
# Epoch 00064: my_iou_metric did not improve from 0.78823
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 65/100
#  - 18s - loss: 0.0712 - my_iou_metric: 0.7881 - val_loss: 0.1211 - val_my_iou_metric: 0.7736
#
# Epoch 00065: my_iou_metric did not improve from 0.78823
# Epoch 66/100
#  - 18s - loss: 0.0711 - my_iou_metric: 0.7900 - val_loss: 0.1254 - val_my_iou_metric: 0.7741
#
# Epoch 00066: my_iou_metric improved from 0.78823 to 0.78997, saving model to Unet_resnet_v4.model
# Epoch 67/100
#  - 18s - loss: 0.0719 - my_iou_metric: 0.7874 - val_loss: 0.1240 - val_my_iou_metric: 0.7791
#
# Epoch 00067: my_iou_metric did not improve from 0.78997
# Epoch 68/100
#  - 18s - loss: 0.0721 - my_iou_metric: 0.7937 - val_loss: 0.1272 - val_my_iou_metric: 0.7751
#
# Epoch 00068: my_iou_metric improved from 0.78997 to 0.79372, saving model to Unet_resnet_v4.model
# Epoch 69/100
#  - 18s - loss: 0.0674 - my_iou_metric: 0.7904 - val_loss: 0.1277 - val_my_iou_metric: 0.7752
#
# Epoch 00069: my_iou_metric did not improve from 0.79372
# Epoch 70/100
#  - 18s - loss: 0.0681 - my_iou_metric: 0.7895 - val_loss: 0.1273 - val_my_iou_metric: 0.7761
#
# Epoch 00070: my_iou_metric did not improve from 0.79372
# Epoch 71/100
#  - 18s - loss: 0.0687 - my_iou_metric: 0.7870 - val_loss: 0.1290 - val_my_iou_metric: 0.7780
#
# Epoch 00071: my_iou_metric did not improve from 0.79372
# Epoch 72/100
#  - 18s - loss: 0.0713 - my_iou_metric: 0.7865 - val_loss: 0.1254 - val_my_iou_metric: 0.7767
#
# Epoch 00072: my_iou_metric did not improve from 0.79372
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 73/100
#  - 18s - loss: 0.0680 - my_iou_metric: 0.7937 - val_loss: 0.1283 - val_my_iou_metric: 0.7788
#
# Epoch 00073: my_iou_metric improved from 0.79372 to 0.79373, saving model to Unet_resnet_v4.model
# Epoch 74/100
#  - 18s - loss: 0.0707 - my_iou_metric: 0.7885 - val_loss: 0.1302 - val_my_iou_metric: 0.7767
#
# Epoch 00074: my_iou_metric did not improve from 0.79373
# Epoch 75/100
#  - 18s - loss: 0.0678 - my_iou_metric: 0.7888 - val_loss: 0.1298 - val_my_iou_metric: 0.7766
#
# Epoch 00075: my_iou_metric did not improve from 0.79373
# Epoch 76/100
#  - 18s - loss: 0.0683 - my_iou_metric: 0.7911 - val_loss: 0.1289 - val_my_iou_metric: 0.7735
#
# Epoch 00076: my_iou_metric did not improve from 0.79373
# Epoch 77/100
#  - 18s - loss: 0.0714 - my_iou_metric: 0.7855 - val_loss: 0.1268 - val_my_iou_metric: 0.7751
#
# Epoch 00077: my_iou_metric did not improve from 0.79373
# Epoch 78/100
#  - 18s - loss: 0.0691 - my_iou_metric: 0.7898 - val_loss: 0.1268 - val_my_iou_metric: 0.7813
#
# Epoch 00078: my_iou_metric did not improve from 0.79373
# Epoch 79/100
#  - 18s - loss: 0.0687 - my_iou_metric: 0.7921 - val_loss: 0.1277 - val_my_iou_metric: 0.7809
#
# Epoch 00079: my_iou_metric did not improve from 0.79373
# Epoch 80/100
#  - 18s - loss: 0.0690 - my_iou_metric: 0.7896 - val_loss: 0.1249 - val_my_iou_metric: 0.7796
#
# Epoch 00080: my_iou_metric did not improve from 0.79373
# Epoch 81/100
#  - 18s - loss: 0.0679 - my_iou_metric: 0.7906 - val_loss: 0.1318 - val_my_iou_metric: 0.7778
#
# Epoch 00081: my_iou_metric did not improve from 0.79373
# Epoch 82/100
#  - 18s - loss: 0.0674 - my_iou_metric: 0.7897 - val_loss: 0.1303 - val_my_iou_metric: 0.7789
#
# Epoch 00082: my_iou_metric did not improve from 0.79373
# Epoch 83/100
#  - 18s - loss: 0.0676 - my_iou_metric: 0.7905 - val_loss: 0.1316 - val_my_iou_metric: 0.7761
#
# Epoch 00083: my_iou_metric did not improve from 0.79373
# Epoch 84/100
#  - 18s - loss: 0.0690 - my_iou_metric: 0.7882 - val_loss: 0.1315 - val_my_iou_metric: 0.7736
#
# Epoch 00084: my_iou_metric did not improve from 0.79373
# Epoch 85/100
#  - 18s - loss: 0.0662 - my_iou_metric: 0.7938 - val_loss: 0.1307 - val_my_iou_metric: 0.7726
#
# Epoch 00085: my_iou_metric improved from 0.79373 to 0.79384, saving model to Unet_resnet_v4.model
# Epoch 86/100
#  - 18s - loss: 0.0663 - my_iou_metric: 0.7922 - val_loss: 0.1317 - val_my_iou_metric: 0.7782
#
# Epoch 00086: my_iou_metric did not improve from 0.79384
# Epoch 87/100
#  - 18s - loss: 0.0669 - my_iou_metric: 0.7892 - val_loss: 0.1331 - val_my_iou_metric: 0.7762
#
# Epoch 00087: my_iou_metric did not improve from 0.79384
# Epoch 88/100
#  - 18s - loss: 0.0672 - my_iou_metric: 0.7931 - val_loss: 0.1347 - val_my_iou_metric: 0.7754
#
# Epoch 00088: my_iou_metric did not improve from 0.79384
# Epoch 89/100
#  - 18s - loss: 0.0673 - my_iou_metric: 0.7912 - val_loss: 0.1342 - val_my_iou_metric: 0.7732
#
# Epoch 00089: my_iou_metric did not improve from 0.79384
# Epoch 90/100
#  - 18s - loss: 0.0664 - my_iou_metric: 0.7943 - val_loss: 0.1312 - val_my_iou_metric: 0.7797
#
# Epoch 00090: my_iou_metric improved from 0.79384 to 0.79431, saving model to Unet_resnet_v4.model
# Epoch 91/100
#  - 18s - loss: 0.0671 - my_iou_metric: 0.7872 - val_loss: 0.1312 - val_my_iou_metric: 0.7785
#
# Epoch 00091: my_iou_metric did not improve from 0.79431
# Epoch 92/100
#  - 18s - loss: 0.0650 - my_iou_metric: 0.7927 - val_loss: 0.1319 - val_my_iou_metric: 0.7799
#
# Epoch 00092: my_iou_metric did not improve from 0.79431
# Epoch 93/100
#  - 18s - loss: 0.0660 - my_iou_metric: 0.7925 - val_loss: 0.1339 - val_my_iou_metric: 0.7720
#
# Epoch 00093: my_iou_metric did not improve from 0.79431
# Epoch 00093: early stopping
# Run time = 0.4796379611227247 hours

# %%
model1 = load_model(save_model_name, custom_objects={'my_iou_metric':my_iou_metric})
# remove activation layer and use lovasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr=0.01)

model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 101, 101, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 101, 101, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 101, 101, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 101, 101, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 101, 101, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 101, 101, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 101, 101, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 101, 101, 16) 0           conv2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 101, 101, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 101, 101, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 101, 101, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 101, 101, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 101, 101, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 101, 101, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 101, 101, 16) 0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50, 50, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 50, 50, 32)   0           conv2d_8[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 32)   0           conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 32)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 25, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 25, 25, 64)   0           conv2d_15[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 12, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 12, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 128)  0           conv2d_18[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 12, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 128)  0           conv2d_20[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 128)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 6, 6, 128)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 6, 6, 256)    295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 6, 6, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 256)    0           conv2d_23[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 6, 6, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 6, 6, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 6, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 6, 6, 256)    590080      activation_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 256)    0           conv2d_25[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 6, 6, 256)    1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 12, 12, 128)  295040      activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 12, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 12, 12, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 128)  147584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 128)  0           conv2d_28[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 12, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 128)  147584      activation_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 128)  0           conv2d_30[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 25, 25, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25, 25, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 25, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 25, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 25, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 25, 25, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 25, 25, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 25, 25, 64)   0           conv2d_33[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 25, 25, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 25, 25, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 25, 25, 64)   0           conv2d_35[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 50, 50, 32)   18464       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 50, 50, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 50, 50, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 50, 50, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 50, 50, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 50, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 50, 50, 32)   0           conv2d_38[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 32)   128         add_15[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 32)   9248        activation_39[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 50, 50, 32)   0           conv2d_40[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 32)   128         add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 101, 101, 16) 4624        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 101, 101, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 101, 101, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 101, 101, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 101, 101, 16) 64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 101, 101, 16) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 101, 101, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 101, 101, 16) 64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 101, 101, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 101, 101, 16) 2320        activation_42[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 101, 101, 16) 0           conv2d_43[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 101, 101, 16) 64          add_17[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 101, 101, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 101, 101, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 101, 101, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 101, 101, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 101, 101, 16) 2320        activation_44[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 101, 101, 16) 0           conv2d_45[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 101, 101, 16) 64          add_18[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 101, 101, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 101, 101, 1)  17          activation_45[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=30, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, 
                              min_lr=0.00005, verbose=1)
epochs = 120
batch_size = 64

t_model2_start = time.time()
history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr,early_stopping], 
                    verbose=2)
t_model2_end = time.time()
print(f"Run time = {(t_model2_end-t_model2_start)/3600} hours")
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/120
#  - 40s - loss: 0.3792 - my_iou_metric_2: 0.6758 - val_loss: 0.3556 - val_my_iou_metric_2: 0.6901
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.69013, saving model to Unet_resnet_v4.model
# Epoch 2/120
#  - 27s - loss: 0.2899 - my_iou_metric_2: 0.6967 - val_loss: 0.7510 - val_my_iou_metric_2: 0.5933
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.69013
# Epoch 3/120
#  - 27s - loss: 0.2528 - my_iou_metric_2: 0.7026 - val_loss: 1.8574 - val_my_iou_metric_2: 0.3139
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.69013
# Epoch 4/120
#  - 27s - loss: 0.1999 - my_iou_metric_2: 0.7180 - val_loss: 0.6765 - val_my_iou_metric_2: 0.6096
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.69013
# Epoch 5/120
#  - 27s - loss: 0.1333 - my_iou_metric_2: 0.7320 - val_loss: 0.4627 - val_my_iou_metric_2: 0.6630
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.69013
# Epoch 6/120
#  - 27s - loss: 0.1073 - my_iou_metric_2: 0.7419 - val_loss: 0.7722 - val_my_iou_metric_2: 0.5776
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.69013
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/120
#  - 27s - loss: 0.0384 - my_iou_metric_2: 0.7582 - val_loss: 0.2826 - val_my_iou_metric_2: 0.7007
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.69013 to 0.70075, saving model to Unet_resnet_v4.model
# Epoch 8/120
#  - 27s - loss: 0.0084 - my_iou_metric_2: 0.7605 - val_loss: -6.6625e-02 - val_my_iou_metric_2: 0.7769
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.70075 to 0.77687, saving model to Unet_resnet_v4.model
# Epoch 9/120
#  - 27s - loss: -2.1257e-02 - my_iou_metric_2: 0.7677 - val_loss: 0.0093 - val_my_iou_metric_2: 0.7698
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.77687
# Epoch 10/120
#  - 27s - loss: -4.9917e-02 - my_iou_metric_2: 0.7771 - val_loss: -8.2176e-02 - val_my_iou_metric_2: 0.7821
#
# Epoch 00010: val_my_iou_metric_2 improved from 0.77687 to 0.78213, saving model to Unet_resnet_v4.model
# Epoch 11/120
#  - 27s - loss: -7.5088e-02 - my_iou_metric_2: 0.7818 - val_loss: 0.0045 - val_my_iou_metric_2: 0.7638
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.78213
# Epoch 12/120
#  - 27s - loss: -7.3388e-02 - my_iou_metric_2: 0.7807 - val_loss: 0.0253 - val_my_iou_metric_2: 0.7590
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.78213
# Epoch 13/120
#  - 27s - loss: -9.2217e-02 - my_iou_metric_2: 0.7850 - val_loss: -1.2839e-01 - val_my_iou_metric_2: 0.7893
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.78213 to 0.78925, saving model to Unet_resnet_v4.model
# Epoch 14/120
#  - 27s - loss: -1.1745e-01 - my_iou_metric_2: 0.7885 - val_loss: 0.0701 - val_my_iou_metric_2: 0.7581
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.78925
# Epoch 15/120
#  - 27s - loss: -1.1685e-01 - my_iou_metric_2: 0.7895 - val_loss: 0.1971 - val_my_iou_metric_2: 0.6964
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.78925
# Epoch 16/120
#  - 27s - loss: -1.3020e-01 - my_iou_metric_2: 0.7913 - val_loss: -8.8813e-02 - val_my_iou_metric_2: 0.7671
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.78925
# Epoch 17/120
#  - 27s - loss: -1.3421e-01 - my_iou_metric_2: 0.7908 - val_loss: 0.0052 - val_my_iou_metric_2: 0.7615
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.78925
# Epoch 18/120
#  - 28s - loss: -1.5255e-01 - my_iou_metric_2: 0.7930 - val_loss: -2.7613e-02 - val_my_iou_metric_2: 0.7639
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.78925
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 19/120
#  - 28s - loss: -2.0463e-01 - my_iou_metric_2: 0.8048 - val_loss: -2.0915e-01 - val_my_iou_metric_2: 0.8065
#
# Epoch 00019: val_my_iou_metric_2 improved from 0.78925 to 0.80650, saving model to Unet_resnet_v4.model
# Epoch 20/120
#  - 28s - loss: -2.3739e-01 - my_iou_metric_2: 0.8105 - val_loss: -1.7805e-01 - val_my_iou_metric_2: 0.8010
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 21/120
#  - 28s - loss: -2.4691e-01 - my_iou_metric_2: 0.8137 - val_loss: -1.9395e-01 - val_my_iou_metric_2: 0.8024
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 22/120
#  - 28s - loss: -2.3979e-01 - my_iou_metric_2: 0.8114 - val_loss: -2.1071e-01 - val_my_iou_metric_2: 0.8049
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 23/120
#  - 28s - loss: -2.5908e-01 - my_iou_metric_2: 0.8171 - val_loss: -1.7610e-01 - val_my_iou_metric_2: 0.8017
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 24/120
#  - 27s - loss: -2.6074e-01 - my_iou_metric_2: 0.8163 - val_loss: -2.0804e-01 - val_my_iou_metric_2: 0.7998
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.80650
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 25/120
#  - 27s - loss: -3.0010e-01 - my_iou_metric_2: 0.8257 - val_loss: -2.4867e-01 - val_my_iou_metric_2: 0.8117
#
# Epoch 00025: val_my_iou_metric_2 improved from 0.80650 to 0.81175, saving model to Unet_resnet_v4.model
# Epoch 26/120
#  - 27s - loss: -3.0646e-01 - my_iou_metric_2: 0.8247 - val_loss: -2.2548e-01 - val_my_iou_metric_2: 0.8081
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.81175
# Epoch 27/120
#  - 27s - loss: -3.2539e-01 - my_iou_metric_2: 0.8296 - val_loss: -2.3341e-01 - val_my_iou_metric_2: 0.8116
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.81175
# Epoch 28/120
#  - 27s - loss: -3.1114e-01 - my_iou_metric_2: 0.8248 - val_loss: -2.2673e-01 - val_my_iou_metric_2: 0.8096
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.81175
# Epoch 29/120
#  - 27s - loss: -3.2751e-01 - my_iou_metric_2: 0.8293 - val_loss: -2.2004e-01 - val_my_iou_metric_2: 0.8097
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.81175
# Epoch 30/120
#  - 27s - loss: -3.3387e-01 - my_iou_metric_2: 0.8309 - val_loss: -2.1782e-01 - val_my_iou_metric_2: 0.8087
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.81175
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 31/120
#  - 27s - loss: -3.5342e-01 - my_iou_metric_2: 0.8354 - val_loss: -2.3939e-01 - val_my_iou_metric_2: 0.8160
#
# Epoch 00031: val_my_iou_metric_2 improved from 0.81175 to 0.81600, saving model to Unet_resnet_v4.model
# Epoch 32/120
#  - 27s - loss: -3.5592e-01 - my_iou_metric_2: 0.8337 - val_loss: -2.1672e-01 - val_my_iou_metric_2: 0.8072
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.81600
# Epoch 33/120
#  - 27s - loss: -3.6028e-01 - my_iou_metric_2: 0.8340 - val_loss: -2.4241e-01 - val_my_iou_metric_2: 0.8158
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.81600
# Epoch 34/120
#  - 27s - loss: -3.7299e-01 - my_iou_metric_2: 0.8365 - val_loss: -2.6569e-01 - val_my_iou_metric_2: 0.8201
#
# Epoch 00034: val_my_iou_metric_2 improved from 0.81600 to 0.82012, saving model to Unet_resnet_v4.model
# Epoch 35/120
#  - 27s - loss: -3.7110e-01 - my_iou_metric_2: 0.8366 - val_loss: -2.4281e-01 - val_my_iou_metric_2: 0.8129
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.82012
# Epoch 36/120
#  - 27s - loss: -3.6976e-01 - my_iou_metric_2: 0.8375 - val_loss: -2.4904e-01 - val_my_iou_metric_2: 0.8113
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.82012
# Epoch 37/120
#  - 27s - loss: -3.7522e-01 - my_iou_metric_2: 0.8384 - val_loss: -2.6752e-01 - val_my_iou_metric_2: 0.8202
#
# Epoch 00037: val_my_iou_metric_2 improved from 0.82012 to 0.82025, saving model to Unet_resnet_v4.model
# Epoch 38/120
#  - 27s - loss: -3.8344e-01 - my_iou_metric_2: 0.8392 - val_loss: -2.5566e-01 - val_my_iou_metric_2: 0.8139
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.82025
# Epoch 39/120
#  - 27s - loss: -3.8379e-01 - my_iou_metric_2: 0.8405 - val_loss: -2.2537e-01 - val_my_iou_metric_2: 0.8105
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.82025
# Epoch 40/120
#  - 27s - loss: -3.8106e-01 - my_iou_metric_2: 0.8401 - val_loss: -2.2352e-01 - val_my_iou_metric_2: 0.8111
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.82025
# Epoch 41/120
#  - 27s - loss: -3.9136e-01 - my_iou_metric_2: 0.8406 - val_loss: -2.4505e-01 - val_my_iou_metric_2: 0.8215
#
# Epoch 00041: val_my_iou_metric_2 improved from 0.82025 to 0.82150, saving model to Unet_resnet_v4.model
# Epoch 42/120
#  - 27s - loss: -3.9394e-01 - my_iou_metric_2: 0.8400 - val_loss: -2.3457e-01 - val_my_iou_metric_2: 0.8106
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 43/120
#  - 27s - loss: -3.9748e-01 - my_iou_metric_2: 0.8420 - val_loss: -2.2504e-01 - val_my_iou_metric_2: 0.8120
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 44/120
#  - 27s - loss: -3.9645e-01 - my_iou_metric_2: 0.8415 - val_loss: -2.4565e-01 - val_my_iou_metric_2: 0.8194
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 45/120
#  - 27s - loss: -4.0016e-01 - my_iou_metric_2: 0.8424 - val_loss: -2.0440e-01 - val_my_iou_metric_2: 0.8106
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 46/120
#  - 27s - loss: -4.0196e-01 - my_iou_metric_2: 0.8427 - val_loss: -2.4749e-01 - val_my_iou_metric_2: 0.8175
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.82150
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/120
#  - 27s - loss: -4.0990e-01 - my_iou_metric_2: 0.8430 - val_loss: -2.3921e-01 - val_my_iou_metric_2: 0.8120
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 48/120
#  - 27s - loss: -4.1135e-01 - my_iou_metric_2: 0.8449 - val_loss: -2.6003e-01 - val_my_iou_metric_2: 0.8204
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 49/120
#  - 27s - loss: -4.1965e-01 - my_iou_metric_2: 0.8469 - val_loss: -2.4444e-01 - val_my_iou_metric_2: 0.8171
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 50/120
#  - 27s - loss: -4.2604e-01 - my_iou_metric_2: 0.8468 - val_loss: -2.5905e-01 - val_my_iou_metric_2: 0.8198
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 51/120
#  - 27s - loss: -4.2489e-01 - my_iou_metric_2: 0.8476 - val_loss: -2.2972e-01 - val_my_iou_metric_2: 0.8146
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.82150
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 52/120
#  - 27s - loss: -4.3364e-01 - my_iou_metric_2: 0.8478 - val_loss: -2.3640e-01 - val_my_iou_metric_2: 0.8165
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 53/120
#  - 27s - loss: -4.3248e-01 - my_iou_metric_2: 0.8481 - val_loss: -2.4966e-01 - val_my_iou_metric_2: 0.8165
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 54/120
#  - 27s - loss: -4.3428e-01 - my_iou_metric_2: 0.8500 - val_loss: -2.4816e-01 - val_my_iou_metric_2: 0.8186
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 55/120
#  - 27s - loss: -4.4225e-01 - my_iou_metric_2: 0.8503 - val_loss: -2.5123e-01 - val_my_iou_metric_2: 0.8199
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 56/120
#  - 27s - loss: -4.2949e-01 - my_iou_metric_2: 0.8474 - val_loss: -2.5226e-01 - val_my_iou_metric_2: 0.8197
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.82150
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 57/120
#  - 27s - loss: -4.3789e-01 - my_iou_metric_2: 0.8506 - val_loss: -2.5365e-01 - val_my_iou_metric_2: 0.8178
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 58/120
#  - 27s - loss: -4.4247e-01 - my_iou_metric_2: 0.8512 - val_loss: -2.5142e-01 - val_my_iou_metric_2: 0.8191
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 59/120
#  - 27s - loss: -4.3695e-01 - my_iou_metric_2: 0.8498 - val_loss: -2.5003e-01 - val_my_iou_metric_2: 0.8173
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 60/120
#  - 27s - loss: -4.3758e-01 - my_iou_metric_2: 0.8494 - val_loss: -2.4161e-01 - val_my_iou_metric_2: 0.8166
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 61/120
#  - 27s - loss: -4.3637e-01 - my_iou_metric_2: 0.8500 - val_loss: -2.4777e-01 - val_my_iou_metric_2: 0.8166
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.82150
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 5e-05.
# Epoch 62/120
#  - 27s - loss: -4.3615e-01 - my_iou_metric_2: 0.8484 - val_loss: -2.4627e-01 - val_my_iou_metric_2: 0.8169
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 63/120
#  - 27s - loss: -4.4112e-01 - my_iou_metric_2: 0.8513 - val_loss: -2.5010e-01 - val_my_iou_metric_2: 0.8190
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 64/120
#  - 27s - loss: -4.3019e-01 - my_iou_metric_2: 0.8470 - val_loss: -2.4769e-01 - val_my_iou_metric_2: 0.8160
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 65/120
#  - 27s - loss: -4.3795e-01 - my_iou_metric_2: 0.8480 - val_loss: -2.4593e-01 - val_my_iou_metric_2: 0.8157
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 66/120
#  - 27s - loss: -4.4341e-01 - my_iou_metric_2: 0.8510 - val_loss: -2.4855e-01 - val_my_iou_metric_2: 0.8174
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 67/120
#  - 27s - loss: -4.4412e-01 - my_iou_metric_2: 0.8509 - val_loss: -2.4620e-01 - val_my_iou_metric_2: 0.8155
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 68/120
#  - 27s - loss: -4.3882e-01 - my_iou_metric_2: 0.8496 - val_loss: -2.4284e-01 - val_my_iou_metric_2: 0.8150
#
# Epoch 00068: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 69/120
#  - 27s - loss: -4.3563e-01 - my_iou_metric_2: 0.8495 - val_loss: -2.4547e-01 - val_my_iou_metric_2: 0.8166
#
# Epoch 00069: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 70/120
#  - 27s - loss: -4.4824e-01 - my_iou_metric_2: 0.8522 - val_loss: -2.4902e-01 - val_my_iou_metric_2: 0.8185
#
# Epoch 00070: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 71/120
#  - 27s - loss: -4.4126e-01 - my_iou_metric_2: 0.8493 - val_loss: -2.4440e-01 - val_my_iou_metric_2: 0.8178
#
# Epoch 00071: val_my_iou_metric_2 did not improve from 0.82150
# Epoch 00071: early stopping
# Run time = 0.5608055801524057 hours

# %%
#plotting train vs validation loss
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
preds_valid = predict_result(model,x_valid,img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
#     temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
        
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# [0.816375 0.818125 0.819125 0.820125 0.820625 0.822625 0.823875 0.825375
#  0.825125 0.825    0.8265   0.82675  0.827125 0.826375 0.826875 0.8265
#  0.826875 0.826    0.825375 0.824875 0.823625 0.822625 0.821875 0.82125
#  0.8215   0.821125 0.820375 0.819875 0.81925  0.82     0.819   ]

# %%
threshold_best_index = np.argmax(ious)
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, 'xr', label='Best threshold')
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
def rle_encode(im):
    '''
    im: numpy array, 1-mask, 0-background
    Returns run length as string
    '''
    pixels = im.flatten(order='F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
preds_test = predict_result(model,x_test,img_size_target)

# %%
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submission_file)

# %% [markdown]
# We get 0.84 iou on test data on kaggle private leaderboard

# %% [markdown]
# Observation
# 1. We split the train data into train and validation stratified by depth column in 80:20 split and do analysis on the data.
# 2. We do augmentation on data like flip and adding noise.
# 3. We use unet model with resnet for training with mean_iou and lovasz loss as eval metric with early stopping and get a loss of 0.82 on validation set.
# 4. We save the model and predict on validation set and find the best threshold which gives the maximum iou for validation set.
# 5. We now use the threshold and model to predict on test set and submit and get a score of 0.840.
